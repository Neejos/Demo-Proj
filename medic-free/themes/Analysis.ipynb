# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
    
import time
import pandas as pd

import requests
import pymongo 
    
driver=webdriver.Firefox(executable_path='C:\webdrivers2\geckodriver.exe')

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States_by_population")
#drop a level from mulitilevel index column

df[0].columns = df[0].columns.droplevel()

# %%
df[0].drop(columns=['2010','April 1, 2010[9]','%[c]','Absolute','Seats','%','Est. pop. perelectoral vote,2019[a]','Est. 2019','2010','2010','Change,2010–2019','% of ElectoralCollege'],inplace=True)

# %%
State_df=df[0]
State_df.dropna(inplace=True)

# %%
State_df.rename(columns={"EstimatedJuly 1, 2019[8]": "Population","Current": "Rank/Population"},inplace=True)

# %%
State_df.Population= State_df.Population.apply(lambda x: x.split('[')[0])

# %%
State_df
# Out:
#     Rank/Population                     State Population
# 0               1.0                California   39512223
# 1               2.0                     Texas   28995881
# 2               3.0                   Florida   21477737
# 3               4.0                  New York   19453561
# 4               5.0              Pennsylvania   12801989
# 5               6.0                  Illinois   12671821
# 6               7.0                      Ohio   11689100
# 7               8.0                   Georgia   10617423
# 8               9.0            North Carolina   10488084
# 9              10.0                  Michigan    9986857
# 10             11.0                New Jersey    8882190
# 11             12.0                  Virginia    8535519
# 12             13.0                Washington    7614893
# 13             14.0                   Arizona    7278717
# 14             15.0             Massachusetts    6892503
# 15             16.0                 Tennessee    6829174
# 16             17.0                   Indiana    6732219
# 17             18.0                  Missouri    6137428
# 18             19.0                  Maryland    6045680
# 19             20.0                 Wisconsin    5822434
# 20             21.0                  Colorado    5758736
# 21             22.0                 Minnesota    5639632
# 22             23.0            South Carolina    5148714
# 23             24.0                   Alabama    4903185
# 24             25.0                 Louisiana    4648794
# 25             26.0                  Kentucky    4467673
# 26             27.0                    Oregon    4217737
# 27             28.0                  Oklahoma    3956971
# 28             29.0               Connecticut    3565287
# 29             30.0                      Utah    3205958
# 30             31.0               Puerto Rico    3193694
# 31             32.0                      Iowa    3155070
# 32             33.0                    Nevada    3080156
# 33             34.0                  Arkansas    3017804
# 34             35.0               Mississippi    2976149
# 35             36.0                    Kansas    2913314
# 36             37.0                New Mexico    2096829
# 37             38.0                  Nebraska    1934408
# 38             39.0             West Virginia    1792147
# 39             40.0                     Idaho    1787065
# 40             41.0                    Hawaii    1415872
# 41             42.0             New Hampshire    1359711
# 42             43.0                     Maine    1344212
# 43             44.0                   Montana    1068778
# 44             45.0              Rhode Island    1059361
# 45             46.0                  Delaware     973764
# 46             47.0              South Dakota     884659
# 47             48.0              North Dakota     762062
# 48             49.0                    Alaska     731545
# 49             50.0      District of Columbia     705749
# 50             51.0                   Vermont     623989
# 51             52.0                   Wyoming     578759
# 52             53.0                      Guam    168,485
# 53             54.0       U.S. Virgin Islands    106,235
# 54             55.0  Northern Mariana Islands     51,433
# 55             56.0            American Samoa     49,437

# %%
US_DEATHS_CASES_Avg=pd.read_html("https://data.cdc.gov/Case-Surveillance/United-States-COVID-19-Cases-and-Deaths-by-State-o/9mfq-cb36")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4c7fac82e0a4> in <module>
# ----> 1 US_DEATHS_CASES_Avg=pd.read_html("https://data.cdc.gov/Case-Surveillance/United-States-COVID-19-Cases-and-Deaths-by-State-o/9mfq-cb36")
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913             break
#     914     else:
# --> 915         raise retained
#     916
#     917     ret = []
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     893
#     894         try:
# --> 895             tables = p.parse_tables()
#     896         except ValueError as caught:
#     897             # if `io` is an io-like object, check if it's seekable
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in parse_tables(self)
#     211         list of parsed (header, body, footer) tuples from tables.
#     212         """
# --> 213         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     214         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     215
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse_tables(self, doc, match, attrs)
#     543
#     544         if not tables:
# --> 545             raise ValueError("No tables found")
#     546
#     547         result = []
#
# ValueError: No tables found

# %%
recs = dictr['result']['records']
df = json_normalize(recs)
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-099bcfcbe3ed> in <module>
#       4 response = requests.get(url)
#       5 dictr = response.json()
# ----> 6 recs = dictr['result']['records']
#       7 df = json_normalize(recs)
#       8 print(df)
#
# TypeError: list indices must be integers or slices, not str

# %%
driver.get("https://covid.cdc.gov/covid-data-tracker/?CDC_AA_refVal=https%3A%2F%2Fwww.cdc.gov%2Fcoronavirus%2F2019-ncov%2Fcases-updates%2Fcases-in-us.html#cases_casesper100klast7days")
# driver.find_element_by_Xpath("/html/body/main/div/div[1]/div/div/div[5]/div[2]/div[1]/button").click()

# %%
# access the slide class which has the div elements that contain both the title and the news
info=driver.find_element_by_class_name("table-info")
soup=bs(info.get_attribute("innerHTML"))
soup
# Out:
# <html><body><div class="general_note" id="table-note" style="margin-top: 10px;">CDC | Updated: Dec  1 2020 12:18PM</div>
# <button aria-label="Download Average Daily Cases per 100k in Last 7 Days" class="ui basic button data-download-btn" data-filetype="us-cases" id="btnUSTableExport" style="color: white !important; background-color: #007c91 !important;" tabindex="0">
#                                     Download Data <i aria-hidden="true" class="fas fa-download"></i>
# </button>
# </body></html>

# %%
try:
    driver.get("https://www.worldometers.info/coronavirus//country/us/")
except:
    pass
src= driver.page_source
# driver.quit()
soup= bs(src, 'lxml')
table= soup.find_all('table')
table= pd.read_html(str(table[1]),header=0)[0]
table
# Out:
#        #               USAState  TotalCases  NewCases  TotalDeaths NewDeaths  \
# 0    NaN              USA Total    13926318  +166,873     274365.0    +1,271
# 1    1.0                  Texas     1267486   +13,479      22057.0       +85
# 2    2.0             California     1234232   +16,491      19210.0       +58
# 3    3.0                Florida      999319    +6,659      18599.0       +99
# 4    4.0               Illinois      726304    +6,190      12985.0      +103
# ..   ...                    ...         ...       ...          ...       ...
# 60  60.0          Navajo Nation       16595      +168        653.0       NaN
# 61  61.0    Grand Princess Ship         103       NaN          3.0       NaN
# 62  62.0      Wuhan Repatriated           3       NaN          NaN       NaN
# 63  63.0  Diamond Princess Ship          46       NaN          NaN       NaN
# 64   NaN                 Total:    13926318  +166,873     274365.0    +1,271
#
#     TotalRecovered  ActiveCases  Tot Cases/1M pop  Deaths/1M pop   TotalTests  \
# 0        8224314.0    5427639.0           42073.0          829.0  194913696.0
# 1        1001641.0     243788.0           43713.0          761.0   11957918.0
# 2         578522.0     636500.0           31237.0          486.0   24025171.0
# 3         656287.0     324433.0           46528.0          866.0   12427765.0
# 4         377936.0     335383.0           57316.0         1025.0   10497998.0
# ..             ...          ...               ...            ...          ...
# 60          9188.0       6754.0               NaN            NaN     158451.0
# 61             NaN        100.0               NaN            NaN          NaN
# 62             NaN          3.0               NaN            NaN          3.0
# 63             NaN         46.0               NaN            NaN         46.0
# 64       8224314.0    5427639.0           42073.0          829.0  194913696.0
#
#     Tests/ 1M pop  Population    Projections
# 0        588858.0         NaN            NaN
# 1        412401.0  28995881.0  [projections]
# 2        608044.0  39512223.0  [projections]
# 3        578635.0  21477737.0  [projections]
# 4        828452.0  12671821.0  [projections]
# ..            ...         ...            ...
# 60            NaN         NaN            NaN
# 61            NaN         NaN            NaN
# 62            NaN         NaN            NaN
# 63            NaN         NaN            NaN
# 64       588858.0         NaN            NaN
#
# [65 rows x 14 columns]

# %%
table.drop(columns=["#","Projections"],inplace=True)

# %%
table.fillna(0)
# Out:
#                  USAState  TotalCases  NewCases  TotalDeaths NewDeaths  \
# 0               USA Total    13926318  +166,873     274365.0    +1,271
# 1                   Texas     1267486   +13,479      22057.0       +85
# 2              California     1234232   +16,491      19210.0       +58
# 3                 Florida      999319    +6,659      18599.0       +99
# 4                Illinois      726304    +6,190      12985.0      +103
# ..                    ...         ...       ...          ...       ...
# 60          Navajo Nation       16595      +168        653.0         0
# 61    Grand Princess Ship         103         0          3.0         0
# 62      Wuhan Repatriated           3         0          0.0         0
# 63  Diamond Princess Ship          46         0          0.0         0
# 64                 Total:    13926318  +166,873     274365.0    +1,271
#
#     TotalRecovered  ActiveCases  Tot Cases/1M pop  Deaths/1M pop   TotalTests  \
# 0        8224314.0    5427639.0           42073.0          829.0  194913696.0
# 1        1001641.0     243788.0           43713.0          761.0   11957918.0
# 2         578522.0     636500.0           31237.0          486.0   24025171.0
# 3         656287.0     324433.0           46528.0          866.0   12427765.0
# 4         377936.0     335383.0           57316.0         1025.0   10497998.0
# ..             ...          ...               ...            ...          ...
# 60          9188.0       6754.0               0.0            0.0     158451.0
# 61             0.0        100.0               0.0            0.0          0.0
# 62             0.0          3.0               0.0            0.0          3.0
# 63             0.0         46.0               0.0            0.0         46.0
# 64       8224314.0    5427639.0           42073.0          829.0  194913696.0
#
#     Tests/ 1M pop  Population
# 0        588858.0         0.0
# 1        412401.0  28995881.0
# 2        608044.0  39512223.0
# 3        578635.0  21477737.0
# 4        828452.0  12671821.0
# ..            ...         ...
# 60            0.0         0.0
# 61            0.0         0.0
# 62            0.0         0.0
# 63            0.0         0.0
# 64       588858.0         0.0
#
# [65 rows x 12 columns]

# %%
table.to_csv("../../data/Cases_Data.csv",header=True,index=False)

# %% [markdown]
# ## Country Data Scrape

# %%
try:
    driver.get("https://www.worldometers.info/coronavirus/#countries/")
except:
    pass
src= driver.page_source
# driver.quit()
soup= bs(src, 'lxml')
table= soup.find_all('table')
table= pd.read_html(str(table[1]),header=0)[0]
table
# Out:
#          #      Country,Other  TotalCases  NewCases  TotalDeaths NewDeaths  \
# 0      NaN              World    63602561  +504,678    1473891.0    +8,429
# 1      1.0                USA    13926318  +166,873     274365.0    +1,271
# 2      2.0              India     9463254   +31,179     137659.0      +482
# 3      3.0             Brazil     6336278   +21,538     173165.0      +317
# 4      4.0             Russia     2295654   +26,338      39895.0      +368
# ..     ...                ...         ...       ...          ...       ...
# 217  217.0   Marshall Islands           4       NaN          NaN       NaN
# 218  218.0  Wallis and Futuna           3       NaN          NaN       NaN
# 219  219.0              Samoa           2       NaN          NaN       NaN
# 220  220.0            Vanuatu           1       NaN          NaN       NaN
# 221    NaN             Total:    63602561  +504,678    1473891.0    +8,429
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 0        43975983.0   18152687.0          105906.0            8160.0
# 1         8224314.0    5427639.0           25307.0           41970.0
# 2         8888595.0     437000.0            8944.0            6829.0
# 3         5601804.0     561309.0            8318.0           29721.0
# 4         1778704.0     477055.0            2300.0           15728.0
# ..              ...          ...               ...               ...
# 217             4.0          0.0               NaN              67.0
# 218             1.0          2.0               NaN             269.0
# 219             NaN          2.0               NaN              10.0
# 220             NaN          1.0               NaN               3.0
# 221      43975983.0   18152687.0          105906.0            8159.6
#
#      Deaths/1M pop   TotalTests  Tests/ 1M pop    Population
# 0            189.1          NaN            NaN           NaN
# 1            827.0  194913696.0       587412.0  3.318174e+08
# 2             99.0  140379976.0       101308.0  1.385679e+09
# 3            812.0   21900000.0       102724.0  2.131930e+08
# 4            273.0   76422849.0       523585.0  1.459609e+08
# ..             ...          ...            ...           ...
# 217            NaN          NaN            NaN  5.935800e+04
# 218            NaN       1149.0       103003.0  1.115500e+04
# 219            NaN          NaN            NaN  1.989670e+05
# 220            NaN          NaN            NaN  3.101060e+05
# 221          189.1          NaN            NaN           NaN
#
# [222 rows x 14 columns]

# %%
table.drop(columns=["#","Projections"],inplace=True)

# %%
# Importing all the required libraries
from bs4 import BeautifulSoup
from splinter import Browser
from selenium import webdriver
import requests
import pandas as pd
import time

# %%
def init_browser():
#Provided a path for the chrome driver
    executable_path ={'executable_path':r'C:\Users\sunandan\Downloads\chromedriver_win32\chromedriver.exe'}
    # executable_path ={'executable_path':r'C:\Users\sunandan\Downloads\chromedriver_win32\chromedriver.exe'}
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.add_argument("--disable-notifications")
    options.add_argument("download.default_directory=C:/Users/sunandan/Documents/Demo-Proj/data")
#     prefs = {"profile.default_content_settings.popups": 0,
#              "download.default_directory": 
#                         r"C:/Users/sunandan/Documents/Demo-Proj/data",#IMPORTANT - ENDING SLASH V IMPORTANT
#              "directory_upgrade": True}
#     options.add_experimental_option("prefs", prefs)
#     browser=webdriver.Chrome(executable_path, chrome_options=options)
#     options.add_argument("download.default_directory=C:/Users/sunandan/Documents/Demo-Proj/data")
    return Browser('chrome',**executable_path,headless=False,options=options)
#     return browser('chrome',**executable_path,headless=False,options=options)
time.sleep(1)
# Out:
# C:\Users\sunandan\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: use options instead of chrome_options
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1206                                          os.fspath(cwd) if cwd is not None else None,
# -> 1207                                          startupinfo)
#    1208             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-f36d8d8976f4> in <module>
#      12 #              "directory_upgrade": True}
#      13 #     options.add_experimental_option("prefs", prefs)
# ---> 14 browser=webdriver.Chrome(executable_path, chrome_options=options)
#      15 #     options.add_argument("download.default_directory=C:/Users/sunandan/Documents/Demo-Proj/data")
#      16 #     return Browser('chrome',**executable_path,headless=False,options=options)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# ~\anaconda3\lib\ntpath.py in basename(p)
#     212 def basename(p):
#     213     """Returns the final component of a pathname"""
# --> 214     return split(p)[1]
#     215
#     216
#
# ~\anaconda3\lib\ntpath.py in split(p)
#     181     Return tuple (head, tail) where tail is everything after the final slash.
#     182     Either part may be empty."""
# --> 183     p = os.fspath(p)
#     184     seps = _get_bothseps(p)
#     185     d, p = splitdrive(p)
#
# TypeError: expected str, bytes or os.PathLike object, not dict

# %%
Browser = init_browser()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1206                                          os.fspath(cwd) if cwd is not None else None,
# -> 1207                                          startupinfo)
#    1208             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-fd898043f717> in <module>
# ----> 1 Browser = init_browser()
#
# <ipython-input-50-f5bec13c9f28> in init_browser()
#      12 #              "directory_upgrade": True}
#      13 #     options.add_experimental_option("prefs", prefs)
# ---> 14     browser=webdriver.Chrome(executable_path, options=options)
#      15 #     options.add_argument("download.default_directory=C:/Users/sunandan/Documents/Demo-Proj/data")
#      16 #     return Browser('chrome',**executable_path,headless=False,options=options)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# ~\anaconda3\lib\ntpath.py in basename(p)
#     212 def basename(p):
#     213     """Returns the final component of a pathname"""
# --> 214     return split(p)[1]
#     215
#     216
#
# ~\anaconda3\lib\ntpath.py in split(p)
#     181     Return tuple (head, tail) where tail is everything after the final slash.
#     182     Either part may be empty."""
# --> 183     p = os.fspath(p)
#     184     seps = _get_bothseps(p)
#     185     d, p = splitdrive(p)
#
# TypeError: expected str, bytes or os.PathLike object, not dict

# %%
browser.visit('https://www.kff.org/other/state-indicator/covid-19-cases-by-race-ethnicity/?currentTimeframe=0&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D')

# %%
browser.find_by_id("table-raw-data").click()
